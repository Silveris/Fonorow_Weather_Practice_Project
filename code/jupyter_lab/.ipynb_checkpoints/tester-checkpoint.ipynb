# %%
# imports
import sys
sys.path.append('../../')
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dont_add.config.api_key import weather_key as wKey
import requests
from scipy.stats import linregress
from pprint import pprint
from citipy import citipy
import random
import datetime

# %%
# paths
out_table_path_base = os.path.join('..','..','output','tables')
out_graph_path_base = os.path.join('..','..','output','graphs')

# %%
# Output File (CSV)
output_data_file = "output/cities.csv"
outPathBase = 'output/'

# Range of latitudes and longitudes for USA
lat_range = (19.50139, 64.85694)
lng_range = (-161.75583, -68.01197)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %%
test_cities = []
for x in range(10):
    test_cities.append(random.choice(cities))

# %%
print(test_cities)
# Out:
# ['porto walter', 'kalga', 'chake chake', 'havelock', 'rikitea', 'yaan', 'batticaloa', 'keighley', 'thompson', 'porbandar']

# %%
# # Build query URL and request your results in Celsius
# url = "http://api.openweathermap.org/data/2.5/weather?"
# city = "Bujumbura"
# units = 'metric'

# # Build query URL
# query_url = f'{url}appid={wKey}&q={city}&units={units}'
# # Get weather data
# weather_response = requests.get(query_url)
# weather = weather_response.json()

# %%
# pprint(weather)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 54},
#  'cod': 200,
#  'coord': {'lat': -3.38, 'lon': 29.36},
#  'dt': 1587946061,
#  'id': 425378,
#  'main': {'feels_like': 21.36,
#           'grnd_level': 926,
#           'humidity': 51,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 21.61,
#           'temp_max': 21.61,
#           'temp_min': 21.61},
#  'name': 'Bujumbura',
#  'rain': {'3h': 0.61},
#  'sys': {'country': 'BI', 'sunrise': 1587959997, 'sunset': 1588003205},
#  'timezone': 7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 109, 'speed': 0.83}}

# %%
# key = ''
# lat = ''
# lon = ''
# exmp_url = f'api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={key}'

# %%
# test_lat = 36.174465
# test_lon = -86.767960
# # lat and lon are for Nashville TN
# test_url = f'http://api.openweathermap.org/data/2.5/weather?'
# units = 'imperial'

# params = {'lat' : test_lat, 'lon' : test_lon, 'appid': wKey, 'units' : units}

# %%
test_weather_response = requests.get(test_url, params=params)
test_resp = test_weather_response.json()

# %%
pprint(test_resp)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 36.17, 'lon': -86.77},
#  'dt': 1587947712,
#  'id': 4644585,
#  'main': {'feels_like': 43.32,
#           'humidity': 54,
#           'pressure': 1021,
#           'temp': 51.53,
#           'temp_max': 53.6,
#           'temp_min': 48.99},
#  'name': 'Nashville',
#  'sys': {'country': 'US',
#          'id': 3477,
#          'sunrise': 1587898748,
#          'sunset': 1587947408,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 9.17}}

# %%
# max_temp_resp = test_resp['main']['temp_max']
# min_temp_resp = test_resp['main']['temp_min']
# cur_temp_resp = test_resp['main']['temp']
# feel_temp_resp = test_resp['main']['feels_like']
# humid_resp = test_resp['main']['humidity']
# vis_resp = test_resp['visibility']
# cloud_resp = test_resp['clouds']['all']
# wind_resp = test_resp['wind']['speed']
# name_resp = test_resp['name']
# country_resp = test_resp['sys']['country']
# press_resp = test_resp['main']['pressure']

# %%
# print(max_temp_resp)
# print(min_temp_resp)
# print(cur_temp_resp)
# print(feel_temp_resp)
# print(humid_resp)
# print(vis_resp)
# print(cloud_resp)
# print(wind_resp)
# print(name_resp)
# print(country_resp)
# print(press_resp)
# Out:
# 53.6
# 48.99
# 51.53
# 43.32
# 54
# 16093
# 75
# 9.17
# Nashville
# US
# 1021

# %%
cur_temps = []
min_temps = []
max_temps = []
feel_temps = []
humidities = []
cloudinessess = []
windSpeeds = []
cityLats = []
cityLngs = []
dates = []
countries = []
names = []
# visibilities = []
pressures = []

# %%
# count = 1
# print('Beginning Data Retrieval')
# print('--------------------------------------')
# for city in cities:
#     url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=imperial'
#     response = requests.get(url).json()
#     print(f'Attempting to save data for {city} : (number{count})')
#     try:
#         names.append(response['name'])
#         temps.append(response['main']['temp_max'])
#         humidities.append(response['main']['humidity'])
#         cloudinessess.append(response['clouds']['all'])
#         windSpeeds.append(response['wind']['speed'])
#         cityLats.append(response['coord']['lat'])
#         cityLngs.append(response['coord']['lon'])
#         dates.append(response['dt'])
#         countries.append(response['sys']['country'])
#     except KeyError:
#         print(f'failed to find all info for {city}, skipping remaining info')
    
#     count += 1
    
# print('--------------------------------------')
# print('Data Retrieval Complete')
# print('--------------------------------------')

# %%
count = 1
print('Beginning Data Retrieval')
print('--------------------------------------')
for city in cities:
    params = {'q' : city, 'appid': wKey, 'units' : units}
    url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={wKey}&units=imperial'
    response = requests.get(url).json()
    print(f'Attempting to save data for {city} : (number{count})')
    try:
        names.append(response['name'])
        max_temps.append(response['main']['temp_max'])
        cur_temps.append(response['main']['temp'])
        min_temps.append(response['main']['temp_min'])
        feel_temps.append(response['main']['feels_like'])
        humidities.append(response['main']['humidity'])
        cloudinessess.append(response['clouds']['all'])
        windSpeeds.append(response['wind']['speed'])
        cityLats.append(response['coord']['lat'])
        cityLngs.append(response['coord']['lon'])
        dates.append(response['dt'])
        countries.append(response['sys']['country'])
        pressures.append(response['main']['pressure'])
    except KeyError:
        print(f'failed to find all info for {city}, skipping remaining info')
    count += 1
    
print('--------------------------------------')
print('Data Retrieval Complete')
print('--------------------------------------')
# Out:
# Beginning Data Retrieval
# --------------------------------------
# Attempting to save data for hilo : (number1)
# Attempting to save data for amalapuram : (number2)
# Attempting to save data for port alfred : (number3)
# Attempting to save data for ushuaia : (number4)
# Attempting to save data for baruun-urt : (number5)
# Attempting to save data for hualmay : (number6)
# Attempting to save data for illapel : (number7)
# Attempting to save data for belushya guba : (number8)
# failed to find all info for belushya guba, skipping remaining info
# Attempting to save data for parral : (number9)
# Attempting to save data for albany : (number10)
# Attempting to save data for tommot : (number11)
# Attempting to save data for chuy : (number12)
# Attempting to save data for thompson : (number13)
# Attempting to save data for bredasdorp : (number14)
# Attempting to save data for salme : (number15)
# Attempting to save data for ambilobe : (number16)
# Attempting to save data for castro : (number17)
# Attempting to save data for oranjemund : (number18)
# Attempting to save data for pouso alegre : (number19)
# Attempting to save data for ponta do sol : (number20)
# Attempting to save data for samusu : (number21)
# failed to find all info for samusu, skipping remaining info
# Attempting to save data for leningradskiy : (number22)
# Attempting to save data for airai : (number23)
# Attempting to save data for east london : (number24)
# Attempting to save data for tsiroanomandidy : (number25)
# Attempting to save data for illoqqortoormiut : (number26)
# failed to find all info for illoqqortoormiut, skipping remaining info
# Attempting to save data for namatanai : (number27)
# Attempting to save data for sitka : (number28)
# Attempting to save data for busselton : (number29)
# Attempting to save data for mizdah : (number30)
# Attempting to save data for kapaa : (number31)
# Attempting to save data for atar : (number32)
# Attempting to save data for ayios kirikos : (number33)
# failed to find all info for ayios kirikos, skipping remaining info
# Attempting to save data for port elizabeth : (number34)
# Attempting to save data for bluff : (number35)
# Attempting to save data for punta arenas : (number36)
# Attempting to save data for khandyga : (number37)
# Attempting to save data for umzimvubu : (number38)
# failed to find all info for umzimvubu, skipping remaining info
# Attempting to save data for rikitea : (number39)
# Attempting to save data for jamestown : (number40)
# Attempting to save data for tsihombe : (number41)
# failed to find all info for tsihombe, skipping remaining info
# Attempting to save data for hasaki : (number42)
# Attempting to save data for torbay : (number43)
# Attempting to save data for isangel : (number44)
# Attempting to save data for kodiak : (number45)
# Attempting to save data for roald : (number46)
# Attempting to save data for iskateley : (number47)
# Attempting to save data for puerto ayora : (number48)
# Attempting to save data for saryozek : (number49)
# Attempting to save data for talnakh : (number50)
# Attempting to save data for saint anthony : (number51)
# Attempting to save data for biloxi : (number52)
# Attempting to save data for vao : (number53)
# Attempting to save data for hobart : (number54)
# Attempting to save data for mataura : (number55)
# Attempting to save data for santa cruz de tenerife : (number56)
# Attempting to save data for lebu : (number57)
# Attempting to save data for yellowknife : (number58)
# Attempting to save data for sisimiut : (number59)
# Attempting to save data for aklavik : (number60)
# Attempting to save data for norman wells : (number61)
# Attempting to save data for arrecife : (number62)
# Attempting to save data for saint simons : (number63)
# Attempting to save data for tasiilaq : (number64)
# Attempting to save data for cidreira : (number65)
# Attempting to save data for greenville : (number66)
# Attempting to save data for attawapiskat : (number67)
# failed to find all info for attawapiskat, skipping remaining info
# Attempting to save data for hami : (number68)
# Attempting to save data for aflu : (number69)
# failed to find all info for aflu, skipping remaining info
# Attempting to save data for sosnovo-ozerskoye : (number70)
# Attempting to save data for pingyin : (number71)
# Attempting to save data for marcona : (number72)
# failed to find all info for marcona, skipping remaining info
# Attempting to save data for chokurdakh : (number73)
# Attempting to save data for sinnamary : (number74)
# Attempting to save data for narsaq : (number75)
# Attempting to save data for stornoway : (number76)
# Attempting to save data for amderma : (number77)
# failed to find all info for amderma, skipping remaining info
# Attempting to save data for barrow : (number78)
# Attempting to save data for porto novo : (number79)
# Attempting to save data for dingle : (number80)
# Attempting to save data for lompoc : (number81)
# Attempting to save data for faanui : (number82)
# Attempting to save data for klaksvik : (number83)
# Attempting to save data for new castle : (number84)
# Attempting to save data for emba : (number85)
# Attempting to save data for tumannyy : (number86)
# failed to find all info for tumannyy, skipping remaining info
# Attempting to save data for cabedelo : (number87)
# Attempting to save data for dubbo : (number88)
# Attempting to save data for atuona : (number89)
# Attempting to save data for nagua : (number90)
# Attempting to save data for skjervoy : (number91)
# Attempting to save data for avarua : (number92)
# Attempting to save data for hamilton : (number93)
# Attempting to save data for georgetown : (number94)
# Attempting to save data for pogar : (number95)
# Attempting to save data for gualeguaychu : (number96)
# Attempting to save data for puerto colombia : (number97)
# Attempting to save data for broken hill : (number98)
# Attempting to save data for sioux lookout : (number99)
# Attempting to save data for storrs : (number100)
# Attempting to save data for danville : (number101)
# Attempting to save data for brigantine : (number102)
# Attempting to save data for borba : (number103)
# Attempting to save data for nikolskoye : (number104)
# Attempting to save data for butaritari : (number105)
# Attempting to save data for det udom : (number106)
# Attempting to save data for qaanaaq : (number107)
# Attempting to save data for portland : (number108)
# Attempting to save data for dikson : (number109)
# Attempting to save data for epe : (number110)
# Attempting to save data for makat : (number111)
# Attempting to save data for petauke : (number112)
# Attempting to save data for moerai : (number113)
# Attempting to save data for saint-pierre : (number114)
# Attempting to save data for port lincoln : (number115)
# Attempting to save data for minab : (number116)
# Attempting to save data for altamont : (number117)
# Attempting to save data for barentsburg : (number118)
# failed to find all info for barentsburg, skipping remaining info
# Attempting to save data for saint-philippe : (number119)
# Attempting to save data for kajaani : (number120)
# Attempting to save data for mayo : (number121)
# Attempting to save data for posse : (number122)
# Attempting to save data for bella union : (number123)
# Attempting to save data for new norfolk : (number124)
# Attempting to save data for esperance : (number125)
# Attempting to save data for taolanaro : (number126)
# failed to find all info for taolanaro, skipping remaining info
# Attempting to save data for cherskiy : (number127)
# Attempting to save data for tuktoyaktuk : (number128)
# Attempting to save data for petropavlovka : (number129)
# Attempting to save data for zhanatas : (number130)
# failed to find all info for zhanatas, skipping remaining info
# Attempting to save data for mujiayingzi : (number131)
# Attempting to save data for aripuana : (number132)
# Attempting to save data for port blair : (number133)
# Attempting to save data for taoudenni : (number134)
# Attempting to save data for brae : (number135)
# Attempting to save data for hofn : (number136)
# Attempting to save data for mar del plata : (number137)
# Attempting to save data for tiksi : (number138)
# Attempting to save data for ahipara : (number139)
# Attempting to save data for kalmar : (number140)
# Attempting to save data for ribeira grande : (number141)
# Attempting to save data for nemuro : (number142)
# Attempting to save data for turtkul : (number143)
# failed to find all info for turtkul, skipping remaining info
# Attempting to save data for fairbanks : (number144)
# Attempting to save data for chagda : (number145)
# failed to find all info for chagda, skipping remaining info
# Attempting to save data for sur : (number146)
# Attempting to save data for hermanus : (number147)
# Attempting to save data for wanxian : (number148)
# Attempting to save data for pevek : (number149)
# Attempting to save data for dunedin : (number150)
# Attempting to save data for tuatapere : (number151)
# Attempting to save data for san quintin : (number152)
# Attempting to save data for kumbo : (number153)
# Attempting to save data for clyde river : (number154)
# Attempting to save data for vaitupu : (number155)
# failed to find all info for vaitupu, skipping remaining info
# Attempting to save data for ucluelet : (number156)
# Attempting to save data for wagga wagga : (number157)
# Attempting to save data for nizhneyansk : (number158)
# failed to find all info for nizhneyansk, skipping remaining info
# Attempting to save data for suntar : (number159)
# Attempting to save data for ilinsko-podomskoye : (number160)
# failed to find all info for ilinsko-podomskoye, skipping remaining info
# Attempting to save data for victoria : (number161)
# Attempting to save data for saldanha : (number162)
# Attempting to save data for el campo : (number163)
# Attempting to save data for ayagoz : (number164)
# Attempting to save data for westport : (number165)
# Attempting to save data for carlos antonio lopez : (number166)
# Attempting to save data for qeshm : (number167)
# Attempting to save data for yarada : (number168)
# Attempting to save data for caucaia : (number169)
# Attempting to save data for outjo : (number170)
# Attempting to save data for kalmunai : (number171)
# Attempting to save data for sao felix do xingu : (number172)
# Attempting to save data for namibe : (number173)
# Attempting to save data for kavieng : (number174)
# Attempting to save data for katobu : (number175)
# Attempting to save data for port-gentil : (number176)
# Attempting to save data for iqaluit : (number177)
# Attempting to save data for qaqortoq : (number178)
# Attempting to save data for champerico : (number179)
# Attempting to save data for ancud : (number180)
# Attempting to save data for carnarvon : (number181)
# Attempting to save data for boa vista : (number182)
# Attempting to save data for igurusi : (number183)
# Attempting to save data for patu : (number184)
# Attempting to save data for asayita : (number185)
# failed to find all info for asayita, skipping remaining info
# Attempting to save data for arraial do cabo : (number186)
# Attempting to save data for manta : (number187)
# Attempting to save data for chernenko : (number188)
# Attempting to save data for sal rei : (number189)
# Attempting to save data for olinda : (number190)
# Attempting to save data for rantepao : (number191)
# Attempting to save data for souillac : (number192)
# Attempting to save data for ubinskoye : (number193)
# Attempting to save data for vanimo : (number194)
# Attempting to save data for grand river south east : (number195)
# failed to find all info for grand river south east, skipping remaining info
# Attempting to save data for port macquarie : (number196)
# Attempting to save data for barcelona : (number197)
# Attempting to save data for dalvik : (number198)
# Attempting to save data for auki : (number199)
# Attempting to save data for andros town : (number200)
# Attempting to save data for muisne : (number201)
# Attempting to save data for college : (number202)
# Attempting to save data for te anau : (number203)
# Attempting to save data for sentyabrskiy : (number204)
# failed to find all info for sentyabrskiy, skipping remaining info
# Attempting to save data for dien bien : (number205)
# failed to find all info for dien bien, skipping remaining info
# Attempting to save data for jawhar : (number206)
# Attempting to save data for port keats : (number207)
# Attempting to save data for nanortalik : (number208)
# Attempting to save data for hithadhoo : (number209)
# Attempting to save data for bandar-e lengeh : (number210)
# Attempting to save data for leer : (number211)
# Attempting to save data for asau : (number212)
# Attempting to save data for yokadouma : (number213)
# Attempting to save data for cape town : (number214)
# Attempting to save data for calabozo : (number215)
# Attempting to save data for mahebourg : (number216)
# Attempting to save data for mahon : (number217)
# Attempting to save data for pochutla : (number218)
# Attempting to save data for xining : (number219)
# Attempting to save data for ust-kulom : (number220)
# Attempting to save data for cabuyaro : (number221)
# Attempting to save data for leh : (number222)
# Attempting to save data for san jose : (number223)
# Attempting to save data for behshahr : (number224)
# Attempting to save data for lolua : (number225)
# failed to find all info for lolua, skipping remaining info
# Attempting to save data for avera : (number226)
# Attempting to save data for saskylakh : (number227)
# Attempting to save data for boulsa : (number228)
# Attempting to save data for tahe : (number229)
# Attempting to save data for lasa : (number230)
# Attempting to save data for jalu : (number231)
# Attempting to save data for kaitangata : (number232)
# Attempting to save data for mitsamiouli : (number233)
# Attempting to save data for maniitsoq : (number234)
# Attempting to save data for marsa matruh : (number235)
# Attempting to save data for pacific grove : (number236)
# Attempting to save data for mount gambier : (number237)
# Attempting to save data for kuybysheve : (number238)
# Attempting to save data for faya : (number239)
# Attempting to save data for yulara : (number240)
# Attempting to save data for coihaique : (number241)
# Attempting to save data for alice springs : (number242)
# Attempting to save data for manaus : (number243)
# Attempting to save data for abha : (number244)
# Attempting to save data for severo-kurilsk : (number245)
# Attempting to save data for ketchikan : (number246)
# Attempting to save data for raudeberg : (number247)
# Attempting to save data for qiongshan : (number248)
# Attempting to save data for kuche : (number249)
# failed to find all info for kuche, skipping remaining info
# Attempting to save data for husavik : (number250)
# Attempting to save data for mrirt : (number251)
# failed to find all info for mrirt, skipping remaining info
# Attempting to save data for neuquen : (number252)
# Attempting to save data for vostok : (number253)
# Attempting to save data for los llanos de aridane : (number254)
# Attempting to save data for luderitz : (number255)
# Attempting to save data for bambous virieux : (number256)
# Attempting to save data for pangnirtung : (number257)
# Attempting to save data for provideniya : (number258)
# Attempting to save data for don sak : (number259)
# Attempting to save data for alugan : (number260)
# Attempting to save data for saint-joseph : (number261)
# Attempting to save data for vaini : (number262)
# Attempting to save data for khatanga : (number263)
# Attempting to save data for yatou : (number264)
# Attempting to save data for padang : (number265)
# Attempting to save data for cayenne : (number266)
# Attempting to save data for plettenberg bay : (number267)
# Attempting to save data for belogorsk : (number268)
# Attempting to save data for umea : (number269)
# Attempting to save data for konevo : (number270)
# Attempting to save data for acapulco : (number271)
# Attempting to save data for sumbe : (number272)
# Attempting to save data for dudinka : (number273)
# Attempting to save data for tura : (number274)
# Attempting to save data for linqing : (number275)
# Attempting to save data for sibolga : (number276)
# Attempting to save data for san patricio : (number277)
# Attempting to save data for kleck : (number278)
# failed to find all info for kleck, skipping remaining info
# Attempting to save data for fomboni : (number279)
# Attempting to save data for mvuma : (number280)
# Attempting to save data for lugovoy : (number281)
# Attempting to save data for launceston : (number282)
# Attempting to save data for glendive : (number283)
# Attempting to save data for kashan : (number284)
# Attempting to save data for ushtobe : (number285)
# Attempting to save data for yeppoon : (number286)
# Attempting to save data for whitianga : (number287)
# Attempting to save data for batemans bay : (number288)
# Attempting to save data for ternate : (number289)
# Attempting to save data for kismayo : (number290)
# Attempting to save data for placido de castro : (number291)
# Attempting to save data for slatina : (number292)
# Attempting to save data for filingue : (number293)
# Attempting to save data for coyah : (number294)
# Attempting to save data for sao filipe : (number295)
# Attempting to save data for saint george : (number296)
# Attempting to save data for tallahassee : (number297)
# Attempting to save data for huarmey : (number298)
# Attempting to save data for balkhash : (number299)
# Attempting to save data for antropovo : (number300)
# Attempting to save data for prince rupert : (number301)
# Attempting to save data for kalasin : (number302)
# Attempting to save data for ozinki : (number303)
# Attempting to save data for achisay : (number304)
# failed to find all info for achisay, skipping remaining info
# Attempting to save data for huangchuan : (number305)
# Attempting to save data for oyama : (number306)
# Attempting to save data for lae : (number307)
# Attempting to save data for yar-sale : (number308)
# Attempting to save data for leshukonskoye : (number309)
# Attempting to save data for calama : (number310)
# Attempting to save data for anchorage : (number311)
# Attempting to save data for ondjiva : (number312)
# Attempting to save data for banjar : (number313)
# Attempting to save data for kieta : (number314)
# Attempting to save data for geraldton : (number315)
# Attempting to save data for akyab : (number316)
# Attempting to save data for makakilo city : (number317)
# Attempting to save data for valenca : (number318)
# Attempting to save data for bengkulu : (number319)
# Attempting to save data for zyryanskoye : (number320)
# Attempting to save data for vila franca do campo : (number321)
# Attempting to save data for mount isa : (number322)
# Attempting to save data for katsuura : (number323)
# Attempting to save data for pemangkat : (number324)
# Attempting to save data for zyryanka : (number325)
# Attempting to save data for constantine : (number326)
# Attempting to save data for porbandar : (number327)
# Attempting to save data for beloha : (number328)
# Attempting to save data for harrison : (number329)
# Attempting to save data for koutiala : (number330)
# Attempting to save data for sola : (number331)
# Attempting to save data for lagoa : (number332)
# Attempting to save data for tilichiki : (number333)
# Attempting to save data for daru : (number334)
# Attempting to save data for neyshabur : (number335)
# Attempting to save data for kapit : (number336)
# Attempting to save data for lidkoping : (number337)
# Attempting to save data for bilma : (number338)
# Attempting to save data for haileybury : (number339)
# Attempting to save data for road town : (number340)
# Attempting to save data for maues : (number341)
# Attempting to save data for kavaratti : (number342)
# Attempting to save data for hovd : (number343)
# Attempting to save data for nishihara : (number344)
# Attempting to save data for manggar : (number345)
# Attempting to save data for shelburne : (number346)
# Attempting to save data for vrangel : (number347)
# Attempting to save data for vila velha : (number348)
# Attempting to save data for hambantota : (number349)
# Attempting to save data for cabo san lucas : (number350)
# Attempting to save data for longyearbyen : (number351)
# Attempting to save data for cienfuegos : (number352)
# Attempting to save data for marion : (number353)
# Attempting to save data for esna : (number354)
# Attempting to save data for sao joao da barra : (number355)
# Attempting to save data for puerto escondido : (number356)
# Attempting to save data for eureka : (number357)
# Attempting to save data for thinadhoo : (number358)
# Attempting to save data for koyelga : (number359)
# Attempting to save data for cascavel : (number360)
# Attempting to save data for temaraia : (number361)
# failed to find all info for temaraia, skipping remaining info
# Attempting to save data for yaring : (number362)
# Attempting to save data for adrar : (number363)
# Attempting to save data for rocha : (number364)
# Attempting to save data for yunyang : (number365)
# Attempting to save data for narbonne : (number366)
# Attempting to save data for akdepe : (number367)
# Attempting to save data for saleaula : (number368)
# failed to find all info for saleaula, skipping remaining info
# Attempting to save data for tanete : (number369)
# Attempting to save data for ostrovnoy : (number370)
# Attempting to save data for kango : (number371)
# Attempting to save data for victor harbor : (number372)
# Attempting to save data for am timan : (number373)
# Attempting to save data for broome : (number374)
# Attempting to save data for mutare : (number375)
# Attempting to save data for kosa : (number376)
# Attempting to save data for aykhal : (number377)
# Attempting to save data for hidalgotitlan : (number378)
# Attempting to save data for aztec : (number379)
# Attempting to save data for halalo : (number380)
# failed to find all info for halalo, skipping remaining info
# Attempting to save data for bethel : (number381)
# Attempting to save data for palana : (number382)
# Attempting to save data for sistranda : (number383)
# Attempting to save data for medicine hat : (number384)
# Attempting to save data for codrington : (number385)
# Attempting to save data for vardo : (number386)
# Attempting to save data for entebbe : (number387)
# Attempting to save data for pudozh : (number388)
# Attempting to save data for upernavik : (number389)
# Attempting to save data for villazon : (number390)
# Attempting to save data for ilulissat : (number391)
# Attempting to save data for moustheni : (number392)
# Attempting to save data for katangli : (number393)
# Attempting to save data for bulanash : (number394)
# Attempting to save data for inverell : (number395)
# Attempting to save data for itarema : (number396)
# Attempting to save data for vestmanna : (number397)
# Attempting to save data for ardakan : (number398)
# Attempting to save data for groningen : (number399)
# Attempting to save data for takaungu : (number400)
# Attempting to save data for ismailia : (number401)
# Attempting to save data for kyle of lochalsh : (number402)
# failed to find all info for kyle of lochalsh, skipping remaining info
# Attempting to save data for fortuna : (number403)
# Attempting to save data for guarapari : (number404)
# Attempting to save data for san cristobal : (number405)
# Attempting to save data for macapa : (number406)
# Attempting to save data for arari : (number407)
# Attempting to save data for saint-georges : (number408)
# Attempting to save data for jaltenango : (number409)
# Attempting to save data for kiunga : (number410)
# Attempting to save data for duobao : (number411)
# Attempting to save data for tabory : (number412)
# Attempting to save data for jarjis : (number413)
# failed to find all info for jarjis, skipping remaining info
# Attempting to save data for somerset east : (number414)
# Attempting to save data for usinsk : (number415)
# Attempting to save data for yumen : (number416)
# Attempting to save data for haibowan : (number417)
# failed to find all info for haibowan, skipping remaining info
# Attempting to save data for minot : (number418)
# Attempting to save data for awbari : (number419)
# Attempting to save data for catio : (number420)
# Attempting to save data for siavonga : (number421)
# Attempting to save data for tromso : (number422)
# Attempting to save data for teplodar : (number423)
# Attempting to save data for buala : (number424)
# Attempting to save data for shubarshi : (number425)
# Attempting to save data for roswell : (number426)
# Attempting to save data for simpang rengam : (number427)
# failed to find all info for simpang rengam, skipping remaining info
# Attempting to save data for savelugu : (number428)
# Attempting to save data for manjo : (number429)
# Attempting to save data for porto velho : (number430)
# Attempting to save data for tual : (number431)
# Attempting to save data for flinders : (number432)
# Attempting to save data for gorontalo : (number433)
# Attempting to save data for phonhong : (number434)
# Attempting to save data for kalga : (number435)
# Attempting to save data for biak : (number436)
# Attempting to save data for ostersund : (number437)
# Attempting to save data for keighley : (number438)
# Attempting to save data for russell : (number439)
# Attempting to save data for lamar : (number440)
# Attempting to save data for kahului : (number441)
# Attempting to save data for pedernales : (number442)
# Attempting to save data for xuddur : (number443)
# Attempting to save data for rungata : (number444)
# failed to find all info for rungata, skipping remaining info
# Attempting to save data for artyk : (number445)
# failed to find all info for artyk, skipping remaining info
# Attempting to save data for walvis bay : (number446)
# Attempting to save data for bosaso : (number447)
# Attempting to save data for teluk nibung : (number448)
# Attempting to save data for tawkar : (number449)
# failed to find all info for tawkar, skipping remaining info
# Attempting to save data for comodoro rivadavia : (number450)
# Attempting to save data for black river : (number451)
# Attempting to save data for shamkhal : (number452)
# Attempting to save data for lebedyn : (number453)
# Attempting to save data for inhambane : (number454)
# Attempting to save data for beringovskiy : (number455)
# Attempting to save data for samalaeulu : (number456)
# failed to find all info for samalaeulu, skipping remaining info
# Attempting to save data for davila : (number457)
# Attempting to save data for tartus : (number458)
# Attempting to save data for las palmas : (number459)
# Attempting to save data for cockburn town : (number460)
# Attempting to save data for buraydah : (number461)
# Attempting to save data for buqayq : (number462)
# failed to find all info for buqayq, skipping remaining info
# Attempting to save data for conakry : (number463)
# Attempting to save data for svetlogorsk : (number464)
# Attempting to save data for chifeng : (number465)
# Attempting to save data for tangping : (number466)
# Attempting to save data for mackay : (number467)
# Attempting to save data for kununurra : (number468)
# Attempting to save data for matara : (number469)
# Attempting to save data for ust-ilimsk : (number470)
# Attempting to save data for camacari : (number471)
# Attempting to save data for dzhebariki-khaya : (number472)
# Attempting to save data for cedar city : (number473)
# Attempting to save data for havelock : (number474)
# Attempting to save data for ranong : (number475)
# Attempting to save data for grindavik : (number476)
# Attempting to save data for keetmanshoop : (number477)
# Attempting to save data for aksu : (number478)
# Attempting to save data for havre : (number479)
# Attempting to save data for tarakan : (number480)
# Attempting to save data for matay : (number481)
# Attempting to save data for fukue : (number482)
# Attempting to save data for bukavu : (number483)
# Attempting to save data for olafsvik : (number484)
# Attempting to save data for monki : (number485)
# Attempting to save data for vega de alatorre : (number486)
# Attempting to save data for urumqi : (number487)
# Attempting to save data for sirnak : (number488)
# Attempting to save data for barbar : (number489)
# failed to find all info for barbar, skipping remaining info
# Attempting to save data for kochubey : (number490)
# Attempting to save data for griffith : (number491)
# Attempting to save data for mnogovershinnyy : (number492)
# Attempting to save data for hilton head island : (number493)
# Attempting to save data for roebourne : (number494)
# Attempting to save data for san ignacio : (number495)
# Attempting to save data for batticaloa : (number496)
# Attempting to save data for chapais : (number497)
# Attempting to save data for benito juarez : (number498)
# Attempting to save data for waipawa : (number499)
# Attempting to save data for nantucket : (number500)
# Attempting to save data for la ronge : (number501)
# Attempting to save data for imbituba : (number502)
# Attempting to save data for nangwa : (number503)
# Attempting to save data for rawannawi : (number504)
# failed to find all info for rawannawi, skipping remaining info
# Attempting to save data for alta floresta : (number505)
# Attempting to save data for gazanjyk : (number506)
# Attempting to save data for umm kaddadah : (number507)
# Attempting to save data for ormara : (number508)
# Attempting to save data for zholymbet : (number509)
# Attempting to save data for sorvag : (number510)
# failed to find all info for sorvag, skipping remaining info
# Attempting to save data for naryan-mar : (number511)
# Attempting to save data for sechura : (number512)
# Attempting to save data for anadyr : (number513)
# Attempting to save data for topolobampo : (number514)
# Attempting to save data for shimoda : (number515)
# Attempting to save data for trelew : (number516)
# Attempting to save data for caravelas : (number517)
# Attempting to save data for lithgow : (number518)
# Attempting to save data for praya : (number519)
# Attempting to save data for saint-francois : (number520)
# Attempting to save data for laramie : (number521)
# Attempting to save data for phalodi : (number522)
# Attempting to save data for porto tolle : (number523)
# Attempting to save data for hauge : (number524)
# Attempting to save data for kattivakkam : (number525)
# Attempting to save data for porto walter : (number526)
# Attempting to save data for tezu : (number527)
# Attempting to save data for grand centre : (number528)
# failed to find all info for grand centre, skipping remaining info
# Attempting to save data for hanko : (number529)
# Attempting to save data for yarke pole : (number530)
# Attempting to save data for zhuhai : (number531)
# Attempting to save data for karachi : (number532)
# Attempting to save data for baghdad : (number533)
# Attempting to save data for mount pleasant : (number534)
# Attempting to save data for paragominas : (number535)
# Attempting to save data for lorengau : (number536)
# Attempting to save data for deputatskiy : (number537)
# Attempting to save data for vestmannaeyjar : (number538)
# Attempting to save data for nhulunbuy : (number539)
# Attempting to save data for berlevag : (number540)
# Attempting to save data for khromtau : (number541)
# Attempting to save data for opuwo : (number542)
# Attempting to save data for sadovo : (number543)
# Attempting to save data for talcahuano : (number544)
# Attempting to save data for port hardy : (number545)
# Attempting to save data for ornskoldsvik : (number546)
# Attempting to save data for coari : (number547)
# Attempting to save data for murray bridge : (number548)
# Attempting to save data for hobyo : (number549)
# Attempting to save data for henties bay : (number550)
# Attempting to save data for domvraina : (number551)
# Attempting to save data for gympie : (number552)
# Attempting to save data for wuwei : (number553)
# Attempting to save data for albi : (number554)
# Attempting to save data for zonguldak : (number555)
# Attempting to save data for nuuk : (number556)
# Attempting to save data for pacifica : (number557)
# Attempting to save data for lock haven : (number558)
# Attempting to save data for santa isabel : (number559)
# Attempting to save data for meulaboh : (number560)
# Attempting to save data for barberton : (number561)
# Attempting to save data for kushima : (number562)
# Attempting to save data for itoman : (number563)
# Attempting to save data for victorville : (number564)
# Attempting to save data for ningan : (number565)
# failed to find all info for ningan, skipping remaining info
# Attempting to save data for burgeo : (number566)
# Attempting to save data for chute-aux-outardes : (number567)
# Attempting to save data for bathsheba : (number568)
# Attempting to save data for yaan : (number569)
# Attempting to save data for abeche : (number570)
# Attempting to save data for chake chake : (number571)
# Attempting to save data for agha jari : (number572)
# failed to find all info for agha jari, skipping remaining info
# Attempting to save data for birao : (number573)
# Attempting to save data for havoysund : (number574)
# Attempting to save data for karonga : (number575)
# Attempting to save data for kukushtan : (number576)
# Attempting to save data for abu zabad : (number577)
# Attempting to save data for palabuhanratu : (number578)
# failed to find all info for palabuhanratu, skipping remaining info
# Attempting to save data for careiro da varzea : (number579)
# Attempting to save data for labuhan : (number580)
# Attempting to save data for key largo : (number581)
# Attempting to save data for nanakuli : (number582)
# Attempting to save data for alto piquiri : (number583)
# Attempting to save data for bonnyville : (number584)
# Attempting to save data for karauzyak : (number585)
# failed to find all info for karauzyak, skipping remaining info
# Attempting to save data for ikoma : (number586)
# Attempting to save data for kamaishi : (number587)
# Attempting to save data for yarmouth : (number588)
# Attempting to save data for williams lake : (number589)
# Attempting to save data for camana : (number590)
# Attempting to save data for galiwinku : (number591)
# failed to find all info for galiwinku, skipping remaining info
# Attempting to save data for japura : (number592)
# Attempting to save data for alakurtti : (number593)
# Attempting to save data for kuhdasht : (number594)
# Attempting to save data for tretten : (number595)
# Attempting to save data for xiongzhou : (number596)
# Attempting to save data for tarnobrzeg : (number597)
# Attempting to save data for verkhnevilyuysk : (number598)
# Attempting to save data for shiyan : (number599)
# Attempting to save data for guerrero negro : (number600)
# Attempting to save data for beira : (number601)
# Attempting to save data for birjand : (number602)
# Attempting to save data for korla : (number603)
# Attempting to save data for miram shah : (number604)
# Attempting to save data for celestun : (number605)
# Attempting to save data for aginskoye : (number606)
# Attempting to save data for bayan : (number607)
# Attempting to save data for leshan : (number608)
# --------------------------------------
# Data Retrieval Complete
# --------------------------------------

# %%
# print('names')
# print(names)
# print('max_temps')
# print(max_temps)
# print('cur_temps')
# print(cur_temps)
# print('min_temps')
# print(min_temps)
# print('feel_temps')
# print(feel_temps)
# print('humidities')
# print(humidities)
# print('cloudinessess')
# print(cloudinessess)
# print('windSpeeds')
# print(windSpeeds)
# print('cityLats')
# print(cityLats)
# print('cityLngs')
# print(cityLngs)
# print('dates')
# print(dates)
# print('countries')
# print(countries)
# print('pressures')
# print(pressures)

# %%
base_df_dict = {
    'City' : names,
    'Cloudiness' : cloudinessess,
    'Country' : countries,
    'Date' : dates,
    'Humidity' : humidities,
    'Lat' : cityLats,
    'Lng' : cityLngs,
    'Current Temp' : cur_temps,
    'Max Temp' : max_temps,
    'Min Temp' : min_temps,
    'Feels Like Temp' : feel_temps,
    'Wind Speed' : windSpeeds,
    'Pressure' : pressures}

base_df = pd.DataFrame(base_df_dict)

# %%
file_name_a = '/base_df'
time_stamp = datetime.date.today()
file_name = f'{file_name_a}_{time_stamp}'
outpath = out_table_path_base + file_name
print(outpath)
base_df.to_csv(outpath)
# Out:
# ..\..\output\tables/base_df_2020-04-27

# %%
def saveTimeStamped(df, base_path, name):
    name = '/' + name
    time_stamp = datetime.date.today()
    file_name = f'{name}_{time_stamp}'
    outpath = base_path + file_name
    df.to_csv(outpath)

# %%
# now = datetime
print(datetime.date.today())
# Out:
# 2020-04-27

# %%
base_df
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Hilo          90      US  1587992111        83  19.73 -155.09
# 1     Amalāpuram          41      IN  1587992239        54  16.58   82.02
# 2    Port Alfred          99      ZA  1587992239        91 -33.59   26.89
# 3        Ushuaia          74      AR  1587992092        75 -54.80  -68.30
# 4     Baruun-Urt           7      MN  1587992240        19  46.68  113.28
# ..           ...         ...     ...         ...       ...    ...     ...
# 554   Miran Shah          59      PK  1587992330        28  33.01   70.07
# 555     Celestún          20      MX  1587992330        84  20.87  -90.40
# 556    Aginskoye          99      RU  1587992330        64  51.10  114.53
# 557        Bayan          97      CN  1587992330        42  46.08  127.40
# 558       Leshan           0      CN  1587992331        25  29.56  103.76
#
#      Current Temp  Max Temp  Min Temp  Feels Like Temp  Wind Speed  Pressure
# 0           66.60     69.80     63.00            67.08        5.82      1018
# 1           88.81     88.81     88.81            92.82        6.40      1008
# 2           64.99     64.99     64.99            68.04        1.99      1022
# 3           41.00     41.00     41.00            34.41        5.82      1011
# 4           64.74     64.74     64.74            51.67       14.61      1009
# ..            ...       ...       ...              ...         ...       ...
# 554         83.03     83.03     83.03            75.61       11.72      1010
# 555         75.97     75.97     75.97            77.31       11.90      1016
# 556         48.51     48.51     48.51            40.89        8.55      1014
# 557         51.30     51.30     51.30            44.40        5.17      1010
# 558         74.43     74.43     74.43            70.45        1.92      1020
#
# [559 rows x 13 columns]

# %%
test_df = base_df.sort_values('City').reset_index(drop=True).copy()

# %%
test_df
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0                  Abhā          40      SA  1587992025        39  18.22
# 1                Abéché          83      TD  1587992325         6  13.83
# 2             Abū Zabad           7      SD  1587992326         6  12.35
# 3    Acapulco de Juárez          40      MX  1587992282        69  16.86
# 4                 Adrar          78      MR  1587992296        12  20.50
# ..                  ...         ...     ...         ...       ...    ...
# 554         Zyryanskoye           0      RU  1587992290        28  56.83
# 555        Örnsköldsvik          69      SE  1587992322        55  63.29
# 556           Östersund          65      SE  1587992192        44  63.18
# 557              Ürümqi          49      CN  1587992313         7  43.80
# 558              Şırnak          40      TR  1587992313        43  37.52
#
#        Lng  Current Temp  Max Temp  Min Temp  Feels Like Temp  Wind Speed  \
# 0    42.51         78.80     78.80     78.80            72.93       11.41
# 1    20.83        111.20    111.20    111.20            98.15       16.11
# 2    29.25        105.31    105.31    105.31            94.19       11.79
# 3   -99.89         75.20     75.20     75.20            78.93        2.24
# 4   -10.07         88.16     88.16     88.16            78.44       10.20
# ..     ...           ...       ...       ...              ...         ...
# 554  86.63         64.18     64.18     64.18            59.31        1.92
# 555  18.72         39.20     39.20     39.20            29.48        9.17
# 556  14.64         41.00     41.00     41.00            30.29       10.29
# 557  87.60         84.20     84.20     84.20            74.88        6.71
# 558  42.46         69.80     69.80     69.80            65.66        5.82
#
#      Pressure
# 0        1024
# 1        1010
# 2        1007
# 3        1013
# 4        1015
# ..        ...
# 554      1016
# 555      1012
# 556      1009
# 557      1010
# 558      1012
#
# [559 rows x 13 columns]

# %%
saveTimeStamped(df=test_df, base_path=out_table_path_base, name='Alphabet_sorted')
